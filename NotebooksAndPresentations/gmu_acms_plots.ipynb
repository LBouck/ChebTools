# %%
import CoolProp
from CoolProp.Plots import PropertyPlot

# %%
plot = PropertyPlot('water', 'ph')
plot.title(r'$p$ vs $h$ for Water')
plot.calc_isolines()
plot.xlabel(r'Specific Enthalpy $h$ [kJ/kg]')
plot.ylabel(r'Pressure $p$ [kPa]')
plot.savefig("hp_water.pdf")
plot.show()
# Out:
# //anaconda/lib/python3.4/site-packages/CoolProp/Plots/Common.py:577: UserWarning: An error occurred for inputs 1023.352540, 620.002650 with index (0,): The temperature of -1545.736103 K is below the minimum of 0.000000 K
#   UserWarning)
# //anaconda/lib/python3.4/site-packages/CoolProp/Plots/Common.py:577: UserWarning: An error occurred for inputs 1023.352540, 648.763203 with index (1,): The temperature of -904.150677 K is below the minimum of 0.000000 K
#   UserWarning)
# //anaconda/lib/python3.4/site-packages/CoolProp/Plots/Common.py:577: UserWarning: An error occurred for inputs 1023.352540, 678.857894 with index (2,): The temperature of -2014.964574 K is below the minimum of 0.000000 K
#   UserWarning)
# //anaconda/lib/python3.4/site-packages/CoolProp/Plots/Common.py:577: UserWarning: An error occurred for inputs 1023.352540, 710.348612 with index (3,): The temperature of -83.803895 K is below the minimum of 0.000000 K
#   UserWarning)
# ...
